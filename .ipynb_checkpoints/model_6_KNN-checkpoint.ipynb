# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0   54.418383     2.479000e-04    -2.479000e-04
# 1                 0   19.899140     1.490000e-05    -1.490000e-05
# 2                 0    1.736952     2.630000e-07    -2.630000e-07
# 3                 0    2.525592     3.760000e-06    -3.760000e-06
# 4                 0    4.134435     1.050000e-05    -1.050000e-05
# ...             ...         ...              ...              ...
# 6986              1    8.589871     1.846000e-04    -1.846000e-04
# 6987              0    0.527699     1.160000e-07    -1.160000e-07
# 6988              0    1.739849     1.780000e-05    -1.780000e-05
# 6989              0    0.681402     2.430000e-06    -2.430000e-06
# 6990              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 0      162.513840          0.003520  ...             -81      4.467
# 1      175.850252          0.000581  ...            -176      4.544
# 2      170.307565          0.000115  ...            -174      4.564
# 3      171.595550          0.001130  ...            -211      4.438
# 4      172.979370          0.001900  ...            -232      4.486
# ...           ...               ...  ...             ...        ...
# 6986   132.016100          0.015700  ...            -152      4.296
# 6987   131.705093          0.000170  ...            -166      4.529
# 6988   133.001270          0.007690  ...            -220      4.444
# 6989   132.181750          0.002850  ...            -236      4.447
# 6990   135.993300          0.010800  ...            -225      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.044          -0.176     0.868          0.233         -0.078
# 2              0.053          -0.168     0.791          0.201         -0.067
# 3              0.070          -0.210     1.046          0.334         -0.133
# 4              0.054          -0.229     0.972          0.315         -0.105
# ...              ...             ...       ...            ...            ...
# 6986           0.231          -0.189     1.088          0.313         -0.228
# 6987           0.035          -0.196     0.903          0.237         -0.079
# 6988           0.056          -0.224     1.031          0.341         -0.114
# 6989           0.056          -0.224     1.041          0.341         -0.114
# 6990           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     297.00482  48.134129      15.436
# 2     285.53461  48.285210      15.597
# 3     288.75488  48.226200      15.509
# 4     296.28613  48.224670      15.714
# ...         ...        ...         ...
# 6986  298.74921  46.973351      14.478
# 6987  297.18875  47.093819      14.082
# 6988  286.50937  47.163219      14.757
# 6989  294.16489  47.176281      15.385
# 6990  297.00977  47.121021      14.826
#
# [6991 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df.drop("koi_disposition", axis=1)
feature_names = selected_features.columns

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# assign X(data) and y(target)
data = selected_features
target = df["koi_disposition"]
#y = df["koi_disposition"].values.reshape(-1, 1)
print(data.shape, target.shape)
# Out:
# (6991, 40) (6991,)

# %%
# split the data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
X_train
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
# ...             ...            ...            ...            ...         ...
# 3772              0              1              0              0    8.268081
# 5191              0              0              0              0   11.161938
# 5226              0              1              0              0    6.150251
# 5390              1              0              0              0    3.343285
# 860               0              0              1              0    2.271907
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
# ...               ...              ...          ...               ...
# 3772     6.340000e-07    -6.340000e-07   135.056330          0.000064
# 5191     1.677000e-04    -1.677000e-04   133.553800          0.013000
# 5226     7.000000e-07    -7.000000e-07   134.422825          0.000088
# 5390     4.380000e-05    -4.380000e-05   134.845100          0.011200
# 860      1.300000e-05    -1.300000e-05   134.798520          0.004670
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
# ...                ...  ...             ...        ...             ...
# 3772         -0.000064  ...            -190      4.502           0.050
# 5191         -0.013000  ...            -124      4.072           0.188
# 5226         -0.000088  ...            -458      3.896           0.270
# 5390         -0.011200  ...            -197      3.773           0.293
# 860          -0.004670  ...            -155      4.506           0.072
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
# ...              ...       ...            ...            ...        ...
# 3772          -0.200     0.922          0.273         -0.091  292.53125
# 5191          -0.101     1.640          0.281         -0.343  295.21268
# 5226          -0.180     2.867          0.988         -1.087  297.18176
# 5390          -0.098     2.652          0.433         -0.939  296.86258
# 860           -0.168     0.856          0.225         -0.096  294.73419
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
# ...         ...         ...
# 3772  46.728699      15.768
# 5191  49.562180      13.374
# 5226  45.988441      10.622
# 5390  41.147419      13.276
# 860   40.861420      14.459
#
# [5243 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# create a random forest classifier to automatically calculate feature importance
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train_scaled, y_train)
rf.score(X_test_scaled, y_test)
# Out:
# 0.897025171624714

# %%
# sort the features by their importance
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.1073467930927034, 'koi_fpflag_co'),
#  (0.09645750830058616, 'koi_fpflag_nt'),
#  (0.06181274339767315, 'koi_fpflag_ss'),
#  (0.05457887274975314, 'koi_model_snr'),
#  (0.051811746223888996, 'koi_prad'),
#  (0.036550856803234034, 'koi_duration_err2'),
#  (0.03493712444733997, 'koi_steff_err1'),
#  (0.03474334383743208, 'koi_duration_err1'),
#  (0.034556696797461574, 'koi_prad_err1'),
#  (0.03203692781034344, 'koi_fpflag_ec'),
#  (0.02981401357465184, 'koi_steff_err2'),
#  (0.027364997908029213, 'koi_prad_err2'),
#  (0.0235795105851598, 'koi_depth'),
#  (0.022517642410222315, 'koi_duration'),
#  (0.022414305828029123, 'koi_time0bk_err1'),
#  (0.021971928697060585, 'koi_time0bk_err2'),
#  (0.02109369505650172, 'koi_period'),
#  (0.019721104001627264, 'koi_impact'),
#  (0.01904866428376804, 'koi_period_err1'),
#  (0.018123303647978012, 'koi_insol_err1'),
#  (0.016400885192893375, 'koi_period_err2'),
#  (0.015527561503656724, 'koi_teq'),
#  (0.014681248744828495, 'koi_depth_err2'),
#  (0.01418381354070467, 'koi_insol'),
#  (0.014059585397885578, 'koi_time0bk'),
#  (0.013448612929898926, 'koi_srad_err1'),
#  (0.0131726089001011, 'koi_depth_err1'),
#  (0.01214568484701028, 'ra'),
#  (0.011892781652763364, 'koi_impact_err1'),
#  (0.011775413682352704, 'koi_impact_err2'),
#  (0.011649794012842595, 'koi_insol_err2'),
#  (0.011519923504380374, 'dec'),
#  (0.011484976872432617, 'koi_slogg_err2'),
#  (0.009941848806920213, 'koi_kepmag'),
#  (0.009884208571846957, 'koi_steff'),
#  (0.009422488783359462, 'koi_srad'),
#  (0.008925369842271404, 'koi_slogg_err1'),
#  (0.00854859095493957, 'koi_slogg'),
#  (0.008239849356919564, 'koi_srad_err2'),
#  (0.002612973448548304, 'koi_tce_plnt_num')]

# %%
print(X_train_scaled.shape, X_test_scaled.shape)
# Out:
# (5243, 40) (1748, 40)

# %%
# use tree-based estimator coupled with SelectFromModel meta-transformer...
# ...to compute impurity-based feature importances and discard irrelevant features 
from sklearn.feature_selection import SelectFromModel
sfmodel = SelectFromModel(rf, prefit=True)
X_train_scaled = sfmodel.transform(X_train_scaled)
X_test_scaled = sfmodel.transform(X_test_scaled)
print(X_train_scaled.shape, X_test_scaled.shape)
# Out:
# (5243, 12) (1748, 12)

# %% [markdown]
# # Train the Model

# %%
# loop through different k values to see which has the highest accuracy
# note: we only use odd numbers because we don't want any ties
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")

plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker='x')
plt.xlabel("k neighbors")
plt.ylabel("Testing Accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.812
# k: 3, Train/Test Score: 0.913/0.834
# k: 5, Train/Test Score: 0.896/0.842
# k: 7, Train/Test Score: 0.888/0.852
# k: 9, Train/Test Score: 0.880/0.852
# k: 11, Train/Test Score: 0.877/0.855
# k: 13, Train/Test Score: 0.875/0.855
# k: 15, Train/Test Score: 0.876/0.854
# k: 17, Train/Test Score: 0.875/0.856
# k: 19, Train/Test Score: 0.874/0.854

# %%
# given that k: 9 provides the best accuracy where the classifier starts to stabilize
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train_scaled, y_train)
print('k=9  Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
# Out:
# k=9  Test Acc: 0.854

# %%
# make predictions
predictions = knn.predict(X_test_scaled)

# %%
# calculate classification report
# precision = true positive / (true positive + false positive)
# recall = true positive / (true positive + false negative)
# f1 = 2*((precision * recall) / (precision + recall)): best at 1, worst at 0
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.72      0.66      0.69       411
#      CONFIRMED       0.74      0.76      0.75       484
# FALSE POSITIVE       0.98      1.00      0.99       853
#
#       accuracy                           0.85      1748
#      macro avg       0.81      0.81      0.81      1748
#   weighted avg       0.85      0.85      0.85      1748

# %%
y_pred = predictions.tolist()
y_test = list(y_test)
pred_df = pd.DataFrame({"Predictions": y_pred, "Actual": y_test})
pred_df.head(10)
# Out:
#       Predictions          Actual
# 0  FALSE POSITIVE  FALSE POSITIVE
# 1       CANDIDATE       CANDIDATE
# 2  FALSE POSITIVE  FALSE POSITIVE
# 3  FALSE POSITIVE  FALSE POSITIVE
# 4  FALSE POSITIVE  FALSE POSITIVE
# 5       CONFIRMED       CONFIRMED
# 6       CONFIRMED       CANDIDATE
# 7       CANDIDATE       CANDIDATE
# 8       CANDIDATE       CANDIDATE
# 9  FALSE POSITIVE  FALSE POSITIVE

# %% [markdown]
# # Save the Model

# %%
import joblib
filename = 'models/exoplanets_KNN.sav'
joblib.dump(knn, filename)
# Out:
# ['models/exoplanets_KNN.sav']
